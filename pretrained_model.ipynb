# %% [markdown]
# <a href="https://colab.research.google.com/github/vasutomar/Kenshi/blob/master/pretrained_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/shivam13juna/Pointer_Generator.git
# Out:
# Cloning into 'Pointer_Generator'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 58 (delta 5), reused 52 (delta 5), pack-reused 0
# Unpacking objects: 100% (58/58), done.

# %%
import os

# %%
# !pip install PyDrive
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
download = drive.CreateFile({'id': '1FIqWhmB2dYHUsP0FWr6r0dc4XSAGizSY'})
download.GetContentFile('model.zip')

# %%
# !unzip model.zip
# Out:
# Archive:  model.zip
#    creating: pretrained_model_tf1.2.1/
#    creating: pretrained_model_tf1.2.1/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238410/
#    creating: pretrained_model_tf1.2.1/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238410/decoded/
#   inflating: pretrained_model_tf1.2.1/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238410/decoded/000000_decoded.txt
#   inflating: pretrained_model_tf1.2.1/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238410/decoded/000001_decoded.txt
#   inflating: pretrained_model_tf1.2.1/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238410/decoded/000002_decoded.txt
#   inflating: pretrained_model_tf1.2.1/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238410/decoded/000003_decoded.txt
#   inflating: pretrained_model_tf1.2.1/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238410/decoded/000004_decoded.txt
# ...

# %%
! mv pretrained_model_tf1.2.1 pretrained_model

# %%
download = drive.CreateFile({'id': '1VraqEMLW21agTMKK00Zb6eM0lpo_Yv_Z'})
download.GetContentFile('finished_files.zip')
# !unzip finished_files.zip
# Out:
# Archive:  finished_files.zip
#    creating: finished_files/
#   inflating: finished_files/test.bin
#   inflating: finished_files/train.bin
#   inflating: finished_files/val.bin
#   inflating: finished_files/vocab
#    creating: finished_files/chunked/
#   inflating: finished_files/chunked/train_127.bin
#   inflating: finished_files/chunked/train_126.bin
#   inflating: finished_files/chunked/train_125.bin
#   inflating: finished_files/chunked/train_124.bin
#   inflating: finished_files/chunked/train_123.bin
#   inflating: finished_files/chunked/train_122.bin
#   inflating: finished_files/chunked/train_121.bin
#   inflating: finished_files/chunked/train_120.bin
#   inflating: finished_files/chunked/train_119.bin
#   inflating: finished_files/chunked/train_118.bin
#   inflating: finished_files/chunked/train_117.bin
#   inflating: finished_files/chunked/train_116.bin
#   inflating: finished_files/chunked/train_115.bin
#   inflating: finished_files/chunked/train_114.bin
# ...

# %%
# !ls
# Out:
# adc.json	finished_files.zip  Pointer_Generator  sample_data
# finished_files	model.zip	    pretrained_model

# %%
os.chdir('Pointer_Generator')

# %%
# !python run_summarization.py --mode=decode --data_path=../finished_files/chunked/val_* --vocab_path=../finished_files/vocab --log_root=./ --exp_name=../pretrained_model --max_enc_steps=400 --max_dec_steps=120 --coverage=1
# Out:
# INFO:tensorflow:Starting seq2seq_attention in decode mode...
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# max_size of vocab was specified as 50000; we now have 50000 words. Stopping reading.
# Finished constructing vocabulary of 50000 total words. Last word added: perisic
# ERROR:tensorflow:Failed to get article or abstract from example
# ERROR:tensorflow:Failed to get article or abstract from example
# ERROR:tensorflow:Failed to get article or abstract from example
# ERROR:tensorflow:Failed to get article or abstract from example
# ERROR:tensorflow:Failed to get article or abstract from example
# ERROR:tensorflow:Failed to get article or abstract from example
# ERROR:tensorflow:Failed to get article or abstract from example
# INFO:tensorflow:Building graph...
# ERROR:tensorflow:Failed to get article or abstract from example
# ERROR:tensorflow:Failed to get article or abstract from example
# ERROR:tensorflow:Failed to get article or abstract from example
# ...

# %%
os.chdir('pointer-generator')

# %%
# !ls
# Out:
# sample_data

# %%
# !pip install pyrouge
# Out:
# ...
#     100% |████████████████████████████████| 61kB 5.6MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/75/d3/0c/e5b04e15b6b87c42e980de3931d2686e14d36e045058983599
# Successfully built pyrouge
# ...
